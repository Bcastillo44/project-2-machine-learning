# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import lag_plot
from pandas import datetime
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/bcas/anaconda3/envs/algotrading/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
df = pd.read_csv("Resources/combined_price_inc_data/att_master.csv")
df.head()
# Out:
#              Date  Close       revenue  costOfRevenue   grossProfit  \
# 0  11/21/83 16:00  61.66  2.141000e+09    696000000.0  1.444000e+09
# 1  11/22/83 16:00  61.09  2.141000e+09    696000000.0  1.444000e+09
# 2  11/23/83 16:00  60.91  2.141000e+09    696000000.0  1.444000e+09
# 3  11/25/83 16:00  61.00  2.141000e+09    696000000.0  1.444000e+09
# 4  11/28/83 16:00  60.34  2.141000e+09    696000000.0  1.444000e+09
#
#    grossProfitRatio  ResearchAndDevelopmentExpenses  \
# 0          0.674451                             0.0
# 1          0.674451                             0.0
# 2          0.674451                             0.0
# 3          0.674451                             0.0
# 4          0.674451                             0.0
#
#    GeneralAndAdministrativeExpenses  SellingAndMarketingExpenses  \
# 0                       484000000.0                          0.0
# 1                       484000000.0                          0.0
# ...

# %%
df.shape
# Out:
# (9332, 28)

# %%
plt.figure()
lag_plot(df['Close'], lag=3)
plt.title('AT&T Stock - Autocorrelation plot with lag = 3')
plt.show()

# %%
plt.plot(df["Date"], df["Close"])
plt.xticks(np.arange(0,9332, 300), df['Date'][0:9332:300])
plt.title("AT&T stock price over time")
plt.xlabel("time")
plt.ylabel("price")
plt.show()

# %%
train_data, test_data = df[0:int(len(df)*0.7)], df[int(len(df)*0.7):]
training_data = train_data['Close'].values
test_data = test_data['Close'].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('Testing Mean Squared Error is {}'.format(MSE_error))
# Out:
# Testing Mean Squared Error is 0.16191102876022684

# %%
train_data.shape
# Out:
# (6532, 28)

# %%
test_set_range = df[int(len(df)*0.7):].index
plt.figure(figsize=(20,10))
plt.plot(test_set_range, model_predictions, color='blue', marker='o', linestyle='dashed',label='Predicted Price')
plt.plot(test_set_range, test_data, color='red', label='Actual Price')
plt.title('AT&T Prices Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.xticks(np.arange(6532,9332,200), df.Date[6532:9332:200])
plt.legend()
plt.show()

# %%
amzn_combined_path = Path('Resources/combined_price_inc_data/amzn_master.csv')
att_combined_path = Path('Resources/combined_price_inc_data/att_master.csv')
boa_combined_path = Path('Resources/combined_price_inc_data/boa_master.csv')
coke_combined_path = Path('Resources/combined_price_inc_data/coke_master.csv')
csx_combined_path = Path('Resources/combined_price_inc_data/csx_master.csv')
jpm_combined_path = Path('Resources/combined_price_inc_data/jpm_master.csv')
odfl_combined_path = Path('Resources/combined_price_inc_data/odfl_master.csv')
pg_combined_path = Path('Resources/combined_price_inc_data/pg_master.csv')
tsla_combined_path = Path('Resources/combined_price_inc_data/tsla_master.csv')
vz_combined_path = Path('Resources/combined_price_inc_data/vz_master.csv')

amzn_comb = pd.read_csv(amzn_combined_path, parse_dates=True, infer_datetime_format=True, index_col='Date')
att_combined = pd.read_csv(att_combined_path, parse_dates=True, infer_datetime_format=True, index_col='Date')
boa_combined = pd.read_csv(boa_combined_path, parse_dates=True, infer_datetime_format=True, index_col='Date')
coke_comb = pd.read_csv(coke_combined_path, parse_dates=True, infer_datetime_format=True, index_col='Date')
csx_combined = pd.read_csv(csx_combined_path, parse_dates=True, infer_datetime_format=True, index_col='Date')
jpm_combined = pd.read_csv(jpm_combined_path, parse_dates=True, infer_datetime_format=True, index_col='Date')
odfl_combined = pd.read_csv(odfl_combined_path, parse_dates=True, infer_datetime_format=True, index_col='Date')
pg_combined = pd.read_csv(pg_combined_path, parse_dates=True, infer_datetime_format=True, index_col='Date')
tsla_comb = pd.read_csv(tsla_combined_path, parse_dates=True, infer_datetime_format=True, index_col='Date')
vz_combined = pd.read_csv(vz_combined_path, parse_dates=True, infer_datetime_format=True, index_col='Date')

# %%
plt.figure()
lag_plot(csx_combined['Close'], lag=3)
plt.title('CSX Stock - Autocorrelation plot with lag = 3')
plt.show()

# %%
train_data, test_data = csx_combined[0:int(len(csx_combined)*0.7)], csx_combined[int(len(csx_combined)*0.7):]
training_data = train_data['Close'].values
test_data = test_data['Close'].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('CSX Mean Squared Error is {}'.format(MSE_error))
# Out:
# /Users/bcas/anaconda3/envs/algotrading/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# CSX Mean Squared Error is 0.6037169578898263

# %%
test_data.shape
# Out:
# (3026,)

# %%
train_data.shape
# Out:
# (7060, 19)

# %%
test_set_range = csx_combined[int(len(csx_combined)*0.7):].index
plt.figure(figsize=(20,10))
plt.plot(test_set_range, model_predictions, color='blue', marker='o',linestyle='dashed',label='Predicted Price')
plt.plot(test_set_range, test_data, color='red', label='Actual Price')
plt.title('CSX Prices Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.xticks(np.arange(7060,10086,200), csx_combined.Date[7060:10086:200])
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-331ee51516b8> in <module>
#       6 plt.xlabel('Date')
#       7 plt.ylabel('Prices')
# ----> 8 plt.xticks(np.arange(7060,10086,200), csx_combined.Date[7060:10086:200])
#       9 plt.legend()
#      10 plt.show()
#
# ~/anaconda3/envs/algotrading/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
amzn_comb_dropped = amzn_comb.dropna()

# %%
amzn_comb_dropped.shape
# Out:
# (5905, 27)

# %%
train_data, test_data = amzn_comb_dropped[0:int(len(amzn_comb_dropped)*0.7)], amzn_comb_dropped[int(len(amzn_comb_dropped)*0.7):]
training_data = train_data["Close"].values
test_data = test_data["Close"].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,2,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('AMZN Mean Squared Error is {}'.format(MSE_error))
# Out:
# AMZN Mean Squared Error is 899.1963929725961

# %%
train_data.shape
# Out:
# (4133, 27)

# %%
test_set_range = amzn_comb_dropped[int(len(amzn_comb_dropped)*0.7):].index
plt.figure(figsize=(20,10))
plt.plot(test_set_range, model_predictions, color='blue', marker='o',linestyle='dashed',label='Predicted Price')
plt.plot(test_set_range, test_data, color='red', label='Actual Price')
plt.title('CSX Prices Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.xticks(np.arange(4133,5905,200), csx_combined.Date[4133:5905:200])
plt.legend()
plt.show()
# Out:
# /Users/bcas/anaconda3/envs/algotrading/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-74be24993872> in <module>
#       6 plt.xlabel('Date')
#       7 plt.ylabel('Prices')
# ----> 8 plt.xticks(np.arange(4133,5905,200), csx_combined.Date[4133:5905:200])
#       9 plt.legend()
#      10 plt.show()
#
# ...

# %%
train_data, test_data = att_combined[0:int(len(att_combined)*0.7)], att_combined[int(len(att_combined)*0.7):]
training_data = train_data['Close'].values
test_data = test_data['Close'].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('ATT Mean Squared Error is {}'.format(MSE_error))
# Out:
# ATT Mean Squared Error is 0.16191102876022684

# %%
att_combined.shape
# Out:
# (9332, 27)

# %%
train_data.shape
# Out:
# (6532, 27)

# %%
test_set_range = att_combined[int(len(att_combined)*0.7):].index
plt.figure(figsize=(20,10))
plt.plot(test_set_range, model_predictions, color='blue', marker='o',linestyle='dashed',label='Predicted Price')
plt.plot(test_set_range, test_data, color='red', label='Actual Price')
plt.title('ATT Prices Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.xticks(np.arange(6532,9332,200), att_combined.Date[6532:9332:200])
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-d987779e3b63> in <module>
#       6 plt.xlabel('Date')
#       7 plt.ylabel('Prices')
# ----> 8 plt.xticks(np.arange(6532,9332,200), att_combined.Date[6532:9332:200])
#       9 plt.legend()
#      10 plt.show()
#
# ~/anaconda3/envs/algotrading/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
train_data, test_data = boa_combined[0:int(len(att_combined)*0.7)], boa_combined[int(len(boa_combined)*0.7):]
training_data = train_data['Close'].values
test_data = test_data['Close'].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('BOA Mean Squared Error is {}'.format(MSE_error))

# %%
test_set_range = boa_combined[int(len(boa_combined)*0.7):].index
plt.plot(test_set_range, model_predictions, color='blue', marker='o',linestyle='dashed',label='Predicted Price')
plt.plot(test_set_range, test_data, color='red', label='Actual Price')
plt.title('BOA Prices Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.xticks(np.arange(881,1259,50), boa_combined.Date[881:1259:50])
plt.legend()
plt.show()

# %%
train_data, test_data = coke_comb[0:int(len(coke_comb)*0.7)], coke_comb[int(len(coke_comb)*0.7):]
training_data = train_data['Close'].values
test_data = test_data['Close'].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,2,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('COKE Mean Squared Error is {}'.format(MSE_error))

# %%
train_data, test_data = jpm_combined[0:int(len(jpm_combined)*0.7)], jpm_combined[int(len(jpm_combined)*0.7):]
training_data = train_data['Close'].values
test_data = test_data['Close'].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('JPM Mean Squared Error is {}'.format(MSE_error))

# %%
train_data, test_data = odfl_combined[0:int(len(odfl_combined)*0.7)], odfl_combined[int(len(odfl_combined)*0.7):]
training_data = train_data['Close'].values
test_data = test_data['Close'].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('ODFL Mean Squared Error is {}'.format(MSE_error))

# %%
train_data, test_data = pg_combined[0:int(len(pg_combined)*0.7)], pg_combined[int(len(pg_combined)*0.7):]
training_data = train_data['Close'].values
test_data = test_data['Close'].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('PG Mean Squared Error is {}'.format(MSE_error))

# %%
train_data, test_data = tsla_comb[0:int(len(tsla_comb)*0.7)], tsla_comb[int(len(tsla_comb)*0.7):]
training_data = train_data['Close'].values
test_data = test_data['Close'].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('TSLA Mean Squared Error is {}'.format(MSE_error))

# %%
train_data, test_data = vz_combined[0:int(len(vz_combined)*0.7)], vz_combined[int(len(vz_combined)*0.7):]
training_data = train_data['Close'].values
test_data = test_data['Close'].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('VZ Mean Squared Error is {}'.format(MSE_error))
